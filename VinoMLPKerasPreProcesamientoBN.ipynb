# %%
#Edgar Moises Hernandez-Gonzalez
#12/11/19
#Vino con MLP normalizando las entradas a la red neuronal con batch normalization

# %%
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization
import matplotlib.pyplot as plt

# %%
wine = load_wine()
x_train, x_test, y_train, y_test = train_test_split(wine.data, wine.target)

# %%
num_classes = 3

# %%
#modelo
model = Sequential()
model.add(BatchNormalization(input_shape=(13,)))
model.add(Dense(100, activation='relu')) #neuronas ocultas, variables de entrada, f(x) de activacion
model.add(Dense(num_classes, activation='softmax')) #clases, f(x) de activacion
# Out:
# WARNING:tensorflow:From C:\Users\EdgarMoises\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# batch_normalization_v1 (Batc (None, 13)                52
# _________________________________________________________________
# dense (Dense)                (None, 100)               1400
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 303
# ...
# Total params: 1,755
# Trainable params: 1,729
# Non-trainable params: 26
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs = 200, batch_size = 128, validation_data=(x_test, y_test))
# Out:
# Train on 133 samples, validate on 45 samples
# Epoch 1/200
# 133/133 [==============================] - 1s 8ms/sample - loss: 1.2038 - acc: 0.3008 - val_loss: 9.3728 - val_acc: 0.3333
# Epoch 2/200
# 133/133 [==============================] - 0s 172us/sample - loss: 1.1344 - acc: 0.3383 - val_loss: 7.8147 - val_acc: 0.3333
# Epoch 3/200
# 133/133 [==============================] - 0s 181us/sample - loss: 1.0760 - acc: 0.3985 - val_loss: 6.7593 - val_acc: 0.3333
# Epoch 4/200
# 133/133 [==============================] - 0s 181us/sample - loss: 1.0066 - acc: 0.4586 - val_loss: 5.1535 - val_acc: 0.3333
# Epoch 5/200
# 133/133 [==============================] - 0s 163us/sample - loss: 0.9526 - acc: 0.4887 - val_loss: 4.5305 - val_acc: 0.3333
# Epoch 6/200
# 133/133 [==============================] - 0s 183us/sample - loss: 0.8991 - acc: 0.5865 - val_loss: 3.7491 - val_acc: 0.3333
# Epoch 7/200
# ...

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.03528419956564903
# Test accuracy: 1.0

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.grid()
plt.xlabel('Epocas')
plt.ylabel('Accuracy')
plt.legend(['train', 'test'])
plt.show()
